# %%
import scanpy as sc
# Read 10x dataset
adata = sc.read_10x_h5("neuron_10k_v3_filtered_feature_bc_matrix.h5")
# Make variable names (in this case the genes) unique
adata.var_names_make_unique()
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# /home/pyrococci/miniconda3/envs/scanpy/lib/python3.6/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
# unfiltered PCA
uf_pca = sc.tl.pca(adata, 10)
sc.pl.pca(adata, components=['1,2'])
# Out:
# /home/pyrococci/miniconda3/envs/scanpy/lib/python3.6/site-packages/anndata/_core/anndata.py:1192: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_string_dtype(df[key]) and not is_categorical(df[key])
# ... storing 'feature_types' as categorical
# ... storing 'genome' as categorical

# %%
# Read 10x dataset
adata = sc.read_10x_h5("neuron_10k_v3_filtered_feature_bc_matrix.h5")
# Make variable names (in this case the genes) unique
adata.var_names_make_unique()


# filtering & PCA
sc.pp.recipe_zheng17(adata)
f_pca = sc.tl.pca(adata, 5)
sc.pl.pca(adata, components=['1,2'])
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# /home/pyrococci/miniconda3/envs/scanpy/lib/python3.6/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# /home/pyrococci/miniconda3/envs/scanpy/lib/python3.6/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):
# /home/pyrococci/miniconda3/envs/scanpy/lib/python3.6/site-packages/anndata/_core/anndata.py:1192: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_string_dtype(df[key]) and not is_categorical(df[key])
# ... storing 'feature_types' as categorical
# ... storing 'genome' as categorical

# %%
sc.pp.neighbors(adata)
sc.tl.leiden(adata)

# %%
sc.tl.tsne(adata)
sc.pl.tsne(adata)
# Out:
# WARNING: Consider installing the package MulticoreTSNE (https://github.com/DmitryUlyanov/Multicore-TSNE). Even for n_jobs=1 this speeds up the computation considerably and might yield better converged results.
